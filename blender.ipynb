# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelmcam/cChess/blob/master/blender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Blender Parameters
renderer = "CYCLES" #@param ["CYCLES", "BLENDER_RENDER"]
frame = 1  #@param {type: "number"}

# %% [markdown]
# #**First upload .blend and script file!!!**

# %%
# !apt install blender
# !apt install libboost-all-dev
# !apt install libgl1-mesa-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# blender is already the newest version (2.79.b+dfsg0-1ubuntu1.18.04.1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libboost-all-dev is already the newest version (1.65.1.0ubuntu1).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# libgl1-mesa-dev is already the newest version (18.2.8-0ubuntu0~18.04.2).
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# 0 upgraded, 0 newly installed, 0 to remove and 7 not upgraded.

# %%
# !blender -b Chess\ Scene.blend -noaudio -o ./test_ -E $renderer -x 1 -P script.py
# Out:
# Read blend: /content/Chess Scene.blend
# [[b'_' b'_' b'_' b'_' b'N' b'_' b'P' b'_']
#  [b'R' b'_' b'_' b'R' b'K' b'n' b'q' b'P']
#  [b'P' b'n' b'_' b'_' b'_' b'p' b'_' b'b']
#  [b'p' b'_' b'_' b'_' b'_' b'_' b'p' b'_']
#  [b'_' b'B' b'_' b'_' b'_' b'B' b'_' b'P']
#  [b'_' b'P' b'P' b'_' b'b' b'Q' b'k' b'p']
#  [b'_' b'r' b'p' b'p' b'_' b'r' b'P' b'N']
#  [b'_' b'P' b'_' b'_' b'p' b'_' b'_' b'p']]
# <bpy_struct, Object("Ambient")>
# <bpy_struct, Object("B0")>
# <bpy_struct, Object("b0")>
# <bpy_struct, Object("B1")>
# <bpy_struct, Object("b1")>
# <bpy_struct, Object("Bishops")>
# <bpy_struct, Object("Bishops.001")>
# <bpy_struct, Object("Black Pieces")>
# <bpy_struct, Object("Camera")>
# <bpy_struct, Object("ChessBoard")>
# <bpy_struct, Object("Chessboard")>
# <bpy_struct, Object("Chessboard Surround")>
# <bpy_struct, Object("Empty")>
# <bpy_struct, Object("k0")>
# <bpy_struct, Object("K0")>
# <bpy_struct, Object("Knights")>
# <bpy_struct, Object("Knights.001")>
# <bpy_struct, Object("Lighting")>
# <bpy_struct, Object("N0")>
# <bpy_struct, Object("n0")>
# <bpy_struct, Object("N1")>
# <bpy_struct, Object("n1")>
# <bpy_struct, Object("P0")>
# <bpy_struct, Object("p0")>
# <bpy_struct, Object("P1")>
# <bpy_struct, Object("p1")>
# <bpy_struct, Object("P2")>
# <bpy_struct, Object("p2")>
# <bpy_struct, Object("P3")>
# <bpy_struct, Object("p3")>
# <bpy_struct, Object("P4")>
# <bpy_struct, Object("p4")>
# <bpy_struct, Object("P5")>
# <bpy_struct, Object("p5")>
# <bpy_struct, Object("P6")>
# <bpy_struct, Object("p6")>
# <bpy_struct, Object("P7")>
# <bpy_struct, Object("p7")>
# <bpy_struct, Object("Pawns")>
# <bpy_struct, Object("Pawns.001")>
# <bpy_struct, Object("q0")>
# <bpy_struct, Object("Q0")>
# <bpy_struct, Object("R0")>
# <bpy_struct, Object("r0")>
# <bpy_struct, Object("R1")>
# <bpy_struct, Object("r1")>
# <bpy_struct, Object("Rooks")>
# <bpy_struct, Object("Rooks.001")>
# <bpy_struct, Object("Sun")>
# <bpy_struct, Object("White Pieces")>
# B0 [4 1]
# B1 [4 5]
# K0 [1 4]
# N0 [0 4]
# N1 [6 7]
# P0 [0 6]
# P1 [1 7]
# P2 [2 0]
# P3 [4 7]
# P4 [5 1]
# P5 [5 2]
# P6 [6 6]
# P7 [7 1]
# Q0 [5 5]
# R0 [1 0]
# R1 [1 3]
# b0 [2 7]
# b1 [5 4]
# k0 [5 6]
# n0 [1 5]
# n1 [2 1]
# p0 [2 5]
# p1 [3 0]
# p2 [3 6]
# p3 [5 7]
# p4 [6 2]
# p5 [6 3]
# p6 [7 4]
# p7 [7 7]
# q0 [1 6]
# r0 [6 1]
# r1 [6 5]
# B0 [4 1]
# B1 [4 5]
# K0 [1 4]
# N0 [0 4]
# N1 [6 7]
# P0 [0 6]
# P1 [1 7]
# P2 [2 0]
# P3 [4 7]
# P4 [5 1]
# P5 [5 2]
# P6 [6 6]
# P7 [7 1]
# Q0 [5 5]
# R0 [1 0]
# R1 [1 3]
# b0 [2 7]
# b1 [5 4]
# k0 [5 6]
# n0 [1 5]
# n1 [2 1]
# p0 [2 5]
# p1 [3 0]
# p2 [3 6]
# p3 [5 7]
# p4 [6 2]
# p5 [6 3]
# p6 [7 4]
# p7 [7 7]
# q0 [1 6]
# r0 [6 1]
# r1 [6 5]
# Fra:1 Mem:54.25M (0.00M, Peak 54.25M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Empty
# Fra:1 Mem:54.25M (0.00M, Peak 54.25M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Sun
# Fra:1 Mem:54.25M (0.00M, Peak 54.25M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Ambient
# Fra:1 Mem:54.25M (0.00M, Peak 54.25M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Black Pieces
# Fra:1 Mem:54.25M (0.00M, Peak 54.25M) | Time:00:00.01 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | k0
# Fra:1 Mem:59.63M (0.00M, Peak 73.16M) | Time:00:00.18 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | q0
# Fra:1 Mem:64.72M (0.00M, Peak 77.53M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Bishops.001
# Fra:1 Mem:64.72M (0.00M, Peak 77.53M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | b1
# Fra:1 Mem:68.44M (0.00M, Peak 77.70M) | Time:00:00.43 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | b0
# Fra:1 Mem:72.15M (0.00M, Peak 81.42M) | Time:00:00.54 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Pawns.001
# Fra:1 Mem:72.15M (0.00M, Peak 81.42M) | Time:00:00.54 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p7
# Fra:1 Mem:74.84M (0.00M, Peak 81.65M) | Time:00:00.61 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p6
# Fra:1 Mem:77.53M (0.00M, Peak 84.34M) | Time:00:00.68 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p5
# Fra:1 Mem:80.22M (0.00M, Peak 87.03M) | Time:00:00.76 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p4
# Fra:1 Mem:82.92M (0.00M, Peak 89.73M) | Time:00:00.83 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p3
# Fra:1 Mem:85.61M (0.00M, Peak 92.42M) | Time:00:00.90 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p2
# Fra:1 Mem:88.30M (0.00M, Peak 95.11M) | Time:00:00.98 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p1
# Fra:1 Mem:90.99M (0.00M, Peak 97.80M) | Time:00:01.05 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p0
# Fra:1 Mem:93.68M (0.00M, Peak 100.49M) | Time:00:01.12 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Knights.001
# Fra:1 Mem:93.68M (0.00M, Peak 100.49M) | Time:00:01.12 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | n1
# Fra:1 Mem:98.51M (0.00M, Peak 123.34M) | Time:00:01.30 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | n0
# Fra:1 Mem:103.34M (0.00M, Peak 128.17M) | Time:00:01.46 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Rooks.001
# Fra:1 Mem:103.34M (0.00M, Peak 128.17M) | Time:00:01.46 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | r0
# Fra:1 Mem:105.92M (0.00M, Peak 128.17M) | Time:00:01.53 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | r1
# Fra:1 Mem:108.51M (0.00M, Peak 128.17M) | Time:00:01.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Chessboard
# Fra:1 Mem:108.51M (0.00M, Peak 128.17M) | Time:00:01.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Chessboard Surround
# Fra:1 Mem:108.51M (0.00M, Peak 128.17M) | Time:00:01.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | ChessBoard
# Fra:1 Mem:108.52M (0.00M, Peak 128.17M) | Time:00:01.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Lighting
# Fra:1 Mem:108.52M (0.00M, Peak 128.17M) | Time:00:01.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | White Pieces
# Fra:1 Mem:108.52M (0.00M, Peak 128.17M) | Time:00:01.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Rooks
# Fra:1 Mem:108.52M (0.00M, Peak 128.17M) | Time:00:01.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | R1
# Fra:1 Mem:110.62M (0.00M, Peak 128.17M) | Time:00:01.62 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | R0
# Fra:1 Mem:112.72M (0.00M, Peak 128.17M) | Time:00:01.64 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Knights
# Fra:1 Mem:112.72M (0.00M, Peak 128.17M) | Time:00:01.64 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | N0
# Fra:1 Mem:116.64M (0.00M, Peak 137.64M) | Time:00:01.69 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | N1
# Fra:1 Mem:120.56M (0.00M, Peak 141.56M) | Time:00:01.75 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Pawns
# Fra:1 Mem:120.56M (0.00M, Peak 141.56M) | Time:00:01.75 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P7
# Fra:1 Mem:122.74M (0.00M, Peak 141.56M) | Time:00:01.76 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P6
# Fra:1 Mem:124.92M (0.00M, Peak 141.56M) | Time:00:01.78 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P5
# Fra:1 Mem:127.11M (0.00M, Peak 141.56M) | Time:00:01.80 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P4
# Fra:1 Mem:129.29M (0.00M, Peak 141.56M) | Time:00:01.82 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P3
# Fra:1 Mem:131.48M (0.00M, Peak 141.56M) | Time:00:01.84 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P2
# Fra:1 Mem:133.66M (0.00M, Peak 141.56M) | Time:00:01.85 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P1
# Fra:1 Mem:134.21M (0.00M, Peak 141.56M) | Time:00:01.86 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P0
# Fra:1 Mem:134.75M (0.00M, Peak 141.56M) | Time:00:01.86 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Bishops
# Fra:1 Mem:134.75M (0.00M, Peak 141.56M) | Time:00:01.86 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | B1
# Fra:1 Mem:137.76M (0.00M, Peak 144.08M) | Time:00:01.89 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | B0
# Fra:1 Mem:140.78M (0.00M, Peak 147.10M) | Time:00:01.92 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Q0
# Fra:1 Mem:144.91M (0.00M, Peak 153.68M) | Time:00:01.96 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | K0
# Fra:1 Mem:149.28M (0.00M, Peak 158.53M) | Time:00:02.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Camera
# Fra:1 Mem:149.28M (0.00M, Peak 158.53M) | Time:00:02.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Initializing
# Fra:1 Mem:149.28M (0.00M, Peak 158.53M) | Time:00:02.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:149.28M (0.00M, Peak 158.53M) | Time:00:02.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Waiting for render to start
# Fra:1 Mem:149.29M (0.00M, Peak 158.53M) | Time:00:02.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene
# Fra:1 Mem:149.29M (0.00M, Peak 158.53M) | Time:00:02.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Shaders
# Fra:1 Mem:201.79M (0.00M, Peak 201.85M) | Time:00:02.25 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Background
# Fra:1 Mem:201.79M (0.00M, Peak 201.85M) | Time:00:02.25 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Camera
# Fra:1 Mem:201.79M (0.00M, Peak 201.85M) | Time:00:02.25 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Meshes Flags
# Fra:1 Mem:201.79M (0.00M, Peak 201.85M) | Time:00:02.25 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Objects
# Fra:1 Mem:201.79M (0.00M, Peak 201.85M) | Time:00:02.25 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.27 | Mem:0.06M, Peak:0.06M | Scene, RenderLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.28 | Mem:0.06M, Peak:0.06M | Scene, RenderLayer | Updating Meshes
# Fra:1 Mem:233.34M (0.00M, Peak 233.34M) | Time:00:02.35 | Mem:0.06M, Peak:0.06M | Scene, RenderLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:243.59M (0.00M, Peak 243.59M) | Time:00:02.36 | Mem:0.06M, Peak:0.06M | Scene, RenderLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:243.59M (0.00M, Peak 253.83M) | Time:00:02.37 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building
# Fra:1 Mem:243.59M (0.00M, Peak 253.83M) | Time:00:02.37 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:02.77 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 2%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:03.03 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 10%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:03.28 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 29%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:03.53 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 47%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:03.78 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 66%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:04.03 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 87%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:04.21 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Packing BVH triangles and strands
# Fra:1 Mem:472.30M (0.00M, Peak 472.30M) | Time:00:04.35 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Packing BVH nodes
# Fra:1 Mem:410.37M (0.00M, Peak 505.01M) | Time:00:04.57 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Copying BVH to device
# Fra:1 Mem:418.26M (0.00M, Peak 505.01M) | Time:00:04.58 | Mem:177.09M, Peak:177.09M | Scene, RenderLayer | Updating Mesh | Computing normals
# Fra:1 Mem:489.24M (0.00M, Peak 505.01M) | Time:00:04.61 | Mem:177.09M, Peak:177.09M | Scene, RenderLayer | Updating Mesh | Copying Mesh to device
# Fra:1 Mem:481.36M (0.00M, Peak 505.01M) | Time:00:04.61 | Mem:248.07M, Peak:248.07M | Scene, RenderLayer | Updating Objects Flags
# Fra:1 Mem:481.36M (0.00M, Peak 505.01M) | Time:00:04.61 | Mem:248.07M, Peak:248.07M | Scene, RenderLayer | Updating Images
# Fra:1 Mem:481.36M (0.00M, Peak 505.01M) | Time:00:04.61 | Mem:248.07M, Peak:248.07M | Scene, RenderLayer | Updating Images | Loading WoodFine0007_L.jpg.001@7
# Fra:1 Mem:481.36M (0.00M, Peak 505.01M) | Time:00:04.61 | Mem:248.07M, Peak:248.07M | Scene, RenderLayer | Updating Images | Loading 14.scratch-textures.jpg.001@14
# Fra:1 Mem:528.84M (0.00M, Peak 530.02M) | Time:00:04.61 | Mem:248.66M, Peak:248.66M | Scene, RenderLayer | Updating Images | Loading WoodFine0007_L.jpg@7
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:299.93M, Peak:299.93M | Scene, RenderLayer | Updating Camera Volume
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:299.93M, Peak:299.93M | Scene, RenderLayer | Updating Hair Systems
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:299.93M, Peak:299.93M | Scene, RenderLayer | Updating Hair settings | Copying Hair settings to device
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:299.93M, Peak:299.93M | Scene, RenderLayer | Updating Lookup Tables
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.18M, Peak:300.18M | Scene, RenderLayer | Updating Lights
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.19M, Peak:300.19M | Scene, RenderLayer | Updating Lights | Computing distribution
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.19M, Peak:300.19M | Scene, RenderLayer | Updating Particle Systems
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.19M, Peak:300.19M | Scene, RenderLayer | Updating Particle Systems | Copying Particles to device
# Fra:1 Mem:481.32M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.19M, Peak:300.19M | Scene, RenderLayer | Updating Integrator
# Fra:1 Mem:481.36M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.23M, Peak:300.23M | Scene, RenderLayer | Updating Film
# Fra:1 Mem:481.37M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.23M, Peak:300.23M | Scene, RenderLayer | Updating Lookup Tables
# Fra:1 Mem:481.37M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.23M, Peak:300.23M | Scene, RenderLayer | Updating Baking
# Fra:1 Mem:481.37M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.23M, Peak:300.23M | Scene, RenderLayer | Updating Device | Writing constant memory
# Fra:1 Mem:481.37M (0.00M, Peak 583.90M) | Time:00:04.68 | Mem:300.23M, Peak:300.23M | Scene, RenderLayer | Path Tracing Tile 0/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:05.51 | Remaining:01:45.88 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 1/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:05.51 | Remaining:01:45.53 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 2/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:06.39 | Remaining:01:49.05 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 3/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:06.42 | Remaining:01:49.05 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 4/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:07.27 | Remaining:01:49.19 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 5/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:07.32 | Remaining:01:49.18 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 6/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:08.15 | Remaining:01:48.73 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 7/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:08.21 | Remaining:01:48.68 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 8/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:09.06 | Remaining:01:48.82 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 9/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:09.14 | Remaining:01:48.78 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 10/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:09.94 | Remaining:01:48.00 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 11/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:10.02 | Remaining:01:47.90 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 12/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:10.83 | Remaining:01:47.13 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 13/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:10.92 | Remaining:01:47.17 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 14/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:11.71 | Remaining:01:46.12 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 15/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:11.78 | Remaining:01:46.04 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 16/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:12.56 | Remaining:01:44.75 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 17/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:12.63 | Remaining:01:44.82 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 18/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:13.83 | Remaining:01:51.14 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 19/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:15.08 | Remaining:01:58.24 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 20/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:15.62 | Remaining:01:59.07 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 21/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:16.05 | Remaining:01:59.73 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 22/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:17.63 | Remaining:02:07.27 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 23/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:18.45 | Remaining:02:10.20 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 24/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:19.29 | Remaining:02:13.09 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 25/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:20.98 | Remaining:02:19.99 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 26/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:21.68 | Remaining:02:21.81 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 27/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:22.67 | Remaining:02:20.95 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 28/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:22.69 | Remaining:02:20.96 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 29/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:24.85 | Remaining:02:27.76 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 30/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:25.54 | Remaining:02:27.63 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 31/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:25.83 | Remaining:02:26.30 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 32/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:26.39 | Remaining:02:24.47 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 33/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:27.08 | Remaining:02:24.27 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 34/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:28.05 | Remaining:02:25.72 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 35/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:29.61 | Remaining:02:28.36 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 36/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:29.92 | Remaining:02:28.37 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 37/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:31.00 | Remaining:02:28.40 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 38/256
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:31.81 | Remaining:02:29.26 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 39/256
#
# Sent an internal break event. Press ^C again to kill Blender
#
# Sent an internal break event. Press ^C again to kill Blender
# Fra:1 Mem:481.51M (0.00M, Peak 583.90M) | Time:00:32.01 | Remaining:02:29.43 | Mem:300.38M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 40/256
# Fra:1 Mem:481.37M (0.00M, Peak 583.90M) | Time:00:32.02 | Remaining:02:29.43 | Mem:300.23M, Peak:300.52M | Scene, RenderLayer | Path Tracing Tile 41/256
# Fra:1 Mem:481.37M (0.00M, Peak 583.90M) | Time:00:32.02 | Remaining:02:29.43 | Mem:300.23M, Peak:300.52M | Scene, RenderLayer | Cancel | Cancelled
# Fra:1 Mem:54.41M (0.00M, Peak 583.90M) | Time:00:32.03 | Sce: Scene Ve:0 Fa:0 La:0
# [[b'_' b'k' b'_' b'_' b'r' b'_' b'_' b'B']
#  [b'R' b'P' b'_' b'r' b'b' b'_' b'B' b'p']
#  [b'_' b'K' b'N' b'_' b'_' b'_' b'p' b'_']
#  [b'q' b'P' b'_' b'n' b'_' b'_' b'P' b'p']
#  [b'_' b'N' b'p' b'_' b'_' b'P' b'_' b'_']
#  [b'p' b'R' b'_' b'_' b'_' b'_' b'Q' b'P']
#  [b'_' b'P' b'_' b'_' b'P' b'_' b'_' b'P']
#  [b'p' b'_' b'_' b'p' b'_' b'n' b'b' b'p']]
# <bpy_struct, Object("Ambient")>
# <bpy_struct, Object("B0")>
# <bpy_struct, Object("b0")>
# <bpy_struct, Object("B1")>
# <bpy_struct, Object("b1")>
# <bpy_struct, Object("Bishops")>
# <bpy_struct, Object("Bishops.001")>
# <bpy_struct, Object("Black Pieces")>
# <bpy_struct, Object("Camera")>
# <bpy_struct, Object("ChessBoard")>
# <bpy_struct, Object("Chessboard")>
# <bpy_struct, Object("Chessboard Surround")>
# <bpy_struct, Object("Empty")>
# <bpy_struct, Object("k0")>
# <bpy_struct, Object("K0")>
# <bpy_struct, Object("Knights")>
# <bpy_struct, Object("Knights.001")>
# <bpy_struct, Object("Lighting")>
# <bpy_struct, Object("N0")>
# <bpy_struct, Object("n0")>
# <bpy_struct, Object("N1")>
# <bpy_struct, Object("n1")>
# <bpy_struct, Object("P0")>
# <bpy_struct, Object("p0")>
# <bpy_struct, Object("P1")>
# <bpy_struct, Object("p1")>
# <bpy_struct, Object("P2")>
# <bpy_struct, Object("p2")>
# <bpy_struct, Object("P3")>
# <bpy_struct, Object("p3")>
# <bpy_struct, Object("P4")>
# <bpy_struct, Object("p4")>
# <bpy_struct, Object("P5")>
# <bpy_struct, Object("p5")>
# <bpy_struct, Object("P6")>
# <bpy_struct, Object("p6")>
# <bpy_struct, Object("P7")>
# <bpy_struct, Object("p7")>
# <bpy_struct, Object("Pawns")>
# <bpy_struct, Object("Pawns.001")>
# <bpy_struct, Object("q0")>
# <bpy_struct, Object("Q0")>
# <bpy_struct, Object("R0")>
# <bpy_struct, Object("r0")>
# <bpy_struct, Object("R1")>
# <bpy_struct, Object("r1")>
# <bpy_struct, Object("Rooks")>
# <bpy_struct, Object("Rooks.001")>
# <bpy_struct, Object("Sun")>
# <bpy_struct, Object("White Pieces")>
# B0 [0 7]
# B1 [1 6]
# K0 [2 1]
# N0 [2 2]
# N1 [4 1]
# P0 [1 1]
# P1 [3 1]
# P2 [3 6]
# P3 [4 5]
# P4 [5 7]
# P5 [6 1]
# P6 [6 4]
# P7 [6 7]
# Q0 [5 6]
# R0 [1 0]
# R1 [5 1]
# b0 [1 4]
# b1 [7 6]
# k0 [0 1]
# n0 [3 3]
# n1 [7 5]
# p0 [1 7]
# p1 [2 6]
# p2 [3 7]
# p3 [4 2]
# p4 [5 0]
# p5 [7 0]
# p6 [7 3]
# p7 [7 7]
# q0 [3 0]
# r0 [0 4]
# r1 [1 3]
# B0 [0 7]
# B1 [1 6]
# K0 [2 1]
# N0 [2 2]
# N1 [4 1]
# P0 [1 1]
# P1 [3 1]
# P2 [3 6]
# P3 [4 5]
# P4 [5 7]
# P5 [6 1]
# P6 [6 4]
# P7 [6 7]
# Q0 [5 6]
# R0 [1 0]
# R1 [5 1]
# b0 [1 4]
# b1 [7 6]
# k0 [0 1]
# n0 [3 3]
# n1 [7 5]
# p0 [1 7]
# p1 [2 6]
# p2 [3 7]
# p3 [4 2]
# p4 [5 0]
# p5 [7 0]
# p6 [7 3]
# p7 [7 7]
# q0 [3 0]
# r0 [0 4]
# r1 [1 3]
# Fra:1 Mem:54.51M (0.00M, Peak 54.51M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Empty
# Fra:1 Mem:54.51M (0.00M, Peak 54.51M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Sun
# Fra:1 Mem:54.51M (0.00M, Peak 54.51M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Ambient
# Fra:1 Mem:54.51M (0.00M, Peak 54.51M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Black Pieces
# Fra:1 Mem:54.51M (0.00M, Peak 54.51M) | Time:00:00.00 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | k0
# Fra:1 Mem:59.89M (0.00M, Peak 73.42M) | Time:00:00.17 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | q0
# Fra:1 Mem:64.98M (0.00M, Peak 77.79M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Bishops.001
# Fra:1 Mem:64.98M (0.00M, Peak 77.79M) | Time:00:00.32 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | b1
# Fra:1 Mem:68.69M (0.00M, Peak 77.96M) | Time:00:00.43 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | b0
# Fra:1 Mem:72.41M (0.00M, Peak 81.68M) | Time:00:00.53 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Pawns.001
# Fra:1 Mem:72.41M (0.00M, Peak 81.68M) | Time:00:00.53 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p7
# Fra:1 Mem:75.10M (0.00M, Peak 81.91M) | Time:00:00.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p6
# Fra:1 Mem:77.79M (0.00M, Peak 84.60M) | Time:00:00.67 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p5
# Fra:1 Mem:80.48M (0.00M, Peak 87.29M) | Time:00:00.75 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p4
# Fra:1 Mem:83.17M (0.00M, Peak 89.98M) | Time:00:00.82 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p3
# Fra:1 Mem:85.87M (0.00M, Peak 92.68M) | Time:00:00.89 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p2
# Fra:1 Mem:88.56M (0.00M, Peak 95.37M) | Time:00:00.96 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p1
# Fra:1 Mem:91.25M (0.00M, Peak 98.06M) | Time:00:01.03 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | p0
# Fra:1 Mem:93.94M (0.00M, Peak 100.75M) | Time:00:01.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Knights.001
# Fra:1 Mem:93.94M (0.00M, Peak 100.75M) | Time:00:01.11 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | n1
# Fra:1 Mem:98.77M (0.00M, Peak 123.60M) | Time:00:01.28 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | n0
# Fra:1 Mem:103.59M (0.00M, Peak 128.43M) | Time:00:01.44 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Rooks.001
# Fra:1 Mem:103.59M (0.00M, Peak 128.43M) | Time:00:01.44 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | r0
# Fra:1 Mem:106.18M (0.00M, Peak 128.43M) | Time:00:01.51 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | r1
# Fra:1 Mem:108.77M (0.00M, Peak 128.43M) | Time:00:01.58 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Chessboard
# Fra:1 Mem:108.77M (0.00M, Peak 128.43M) | Time:00:01.58 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Chessboard Surround
# Fra:1 Mem:108.77M (0.00M, Peak 128.43M) | Time:00:01.58 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | ChessBoard
# Fra:1 Mem:108.78M (0.00M, Peak 128.43M) | Time:00:01.58 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Lighting
# Fra:1 Mem:108.78M (0.00M, Peak 128.43M) | Time:00:01.58 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | White Pieces
# Fra:1 Mem:108.78M (0.00M, Peak 128.43M) | Time:00:01.58 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Rooks
# Fra:1 Mem:108.78M (0.00M, Peak 128.43M) | Time:00:01.58 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | R1
# Fra:1 Mem:110.88M (0.00M, Peak 128.43M) | Time:00:01.60 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | R0
# Fra:1 Mem:112.98M (0.00M, Peak 128.43M) | Time:00:01.62 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Knights
# Fra:1 Mem:112.98M (0.00M, Peak 128.43M) | Time:00:01.62 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | N0
# Fra:1 Mem:116.90M (0.00M, Peak 137.90M) | Time:00:01.67 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | N1
# Fra:1 Mem:120.81M (0.00M, Peak 141.82M) | Time:00:01.72 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Pawns
# Fra:1 Mem:120.81M (0.00M, Peak 141.82M) | Time:00:01.72 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P7
# Fra:1 Mem:123.00M (0.00M, Peak 141.82M) | Time:00:01.73 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P6
# Fra:1 Mem:125.18M (0.00M, Peak 141.82M) | Time:00:01.75 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P5
# Fra:1 Mem:127.36M (0.00M, Peak 141.82M) | Time:00:01.77 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P4
# Fra:1 Mem:129.55M (0.00M, Peak 141.82M) | Time:00:01.79 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P3
# Fra:1 Mem:131.73M (0.00M, Peak 141.82M) | Time:00:01.81 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P2
# Fra:1 Mem:133.92M (0.00M, Peak 141.82M) | Time:00:01.83 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P1
# Fra:1 Mem:134.46M (0.00M, Peak 141.82M) | Time:00:01.83 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | P0
# Fra:1 Mem:135.01M (0.00M, Peak 141.82M) | Time:00:01.84 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Bishops
# Fra:1 Mem:135.01M (0.00M, Peak 141.82M) | Time:00:01.84 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | B1
# Fra:1 Mem:138.02M (0.00M, Peak 144.34M) | Time:00:01.86 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | B0
# Fra:1 Mem:141.03M (0.00M, Peak 147.35M) | Time:00:01.89 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Q0
# Fra:1 Mem:145.16M (0.00M, Peak 153.94M) | Time:00:01.93 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | K0
# Fra:1 Mem:149.53M (0.00M, Peak 158.79M) | Time:00:01.97 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Synchronizing object | Camera
# Fra:1 Mem:149.53M (0.00M, Peak 158.79M) | Time:00:01.97 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Initializing
# Fra:1 Mem:149.53M (0.00M, Peak 158.79M) | Time:00:01.97 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Loading render kernels (may take a few minutes the first time)
# Fra:1 Mem:149.53M (0.00M, Peak 158.79M) | Time:00:01.97 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Waiting for render to start
# Fra:1 Mem:149.54M (0.00M, Peak 158.79M) | Time:00:01.97 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Scene
# Fra:1 Mem:149.54M (0.00M, Peak 158.79M) | Time:00:01.97 | Mem:0.00M, Peak:0.00M | Scene, RenderLayer | Updating Shaders
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.12 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Background
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.12 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Camera
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.12 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Meshes Flags
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.12 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Objects
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.12 | Mem:0.05M, Peak:0.05M | Scene, RenderLayer | Updating Objects | Copying Transformations to device
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.14 | Mem:0.06M, Peak:0.06M | Scene, RenderLayer | Updating Objects | Applying Static Transformations
# Fra:1 Mem:201.80M (0.00M, Peak 201.85M) | Time:00:02.15 | Mem:0.06M, Peak:0.06M | Scene, RenderLayer | Updating Meshes
# Fra:1 Mem:233.35M (0.00M, Peak 233.35M) | Time:00:02.22 | Mem:0.06M, Peak:0.06M | Scene, RenderLayer | Updating Mesh | Computing attributes
# Fra:1 Mem:243.60M (0.00M, Peak 243.60M) | Time:00:02.22 | Mem:0.06M, Peak:0.06M | Scene, RenderLayer | Updating Mesh | Copying Attributes to device
# Fra:1 Mem:243.60M (0.00M, Peak 253.84M) | Time:00:02.23 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building
# Fra:1 Mem:243.60M (0.00M, Peak 253.84M) | Time:00:02.23 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:02.61 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 1%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:02.88 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 5%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:03.14 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 22%, duplicates 0%
# Fra:1 Mem:361.89M (0.00M, Peak 361.89M) | Time:00:03.39 | Mem:10.31M, Peak:10.31M | Scene, RenderLayer | Updating Scene BVH | Building BVH 38%, duplicates 0%
#
# Blender killed
# ^C
