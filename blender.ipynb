# %% [markdown]
# <a href="https://colab.research.google.com/github/rafaelmcam/cChess/blob/master/blender.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#@title Blender Parameters
renderer = "CYCLES" #@param ["CYCLES", "BLENDER_RENDER"]
frame = 1  #@param {type: "number"}

# %% [markdown]
# #**First upload .blend and script file!!!**

# %%
# !apt install blender
# !apt install libboost-all-dev
# !apt install libgl1-mesa-dev
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following package was automatically installed and is no longer required:
#   libnvidia-common-410
# Use 'apt autoremove' to remove it.
# The following additional packages will be installed:
#   blender-data fonts-dejavu fonts-dejavu-core fonts-dejavu-extra libblosc1
#   libglew2.0 libjemalloc1 liblog4cplus-1.1-9 libopencolorio1v5
#   libopenimageio1.7 libopenvdb5.0 libraw16 libspnav0 libtinyxml2.6.2v5
#   libyaml-cpp0.5v5
# Suggested packages:
#   glew-utils spacenavd
# The following NEW packages will be installed:
#   blender blender-data fonts-dejavu fonts-dejavu-core fonts-dejavu-extra
#   libblosc1 libglew2.0 libjemalloc1 liblog4cplus-1.1-9 libopencolorio1v5
#   libopenimageio1.7 libopenvdb5.0 libraw16 libspnav0 libtinyxml2.6.2v5
#   libyaml-cpp0.5v5
# 0 upgraded, 16 newly installed, 0 to remove and 7 not upgraded.
# Need to get 45.2 MB of archives.
# ...

# %%
# !mkdir Dcs
# Out:
# mkdir: cannot create directory ‘Dcs’: File exists

# %%
# !mkdir Boards
# Out:
# mkdir: cannot create directory ‘Boards’: File exists

# %%
# !blender -b Chess\ Scene.blend -noaudio -o ./test_ -E $renderer -x 1 -P script.py
# Out:
# Read blend: /content/Chess Scene.blend
# [[b'_' b'_' b'_' b'P' b'_' b'_' b'_' b'_']
#  [b'p' b'P' b'_' b'r' b'_' b'_' b'N' b'Q']
#  [b'B' b'_' b'q' b'r' b'p' b'_' b'_' b'_']
#  [b'_' b'B' b'_' b'p' b'p' b'N' b'_' b'b']
#  [b'_' b'P' b'P' b'_' b'_' b'p' b'R' b'n']
#  [b'P' b'K' b'_' b'_' b'_' b'_' b'p' b'_']
#  [b'p' b'_' b'_' b'_' b'_' b'n' b'P' b'p']
#  [b'P' b'_' b'_' b'_' b'P' b'b' b'R' b'k']]
# B0 [2 0]
# B1 [3 1]
# K0 [5 1]
# N0 [1 6]
# N1 [3 5]
# P0 [0 3]
# P1 [1 1]
# P2 [4 1]
# P3 [4 2]
# P4 [5 0]
# P5 [6 6]
# P6 [7 0]
# P7 [7 4]
# Q0 [1 7]
# R0 [4 6]
# R1 [7 6]
# b0 [3 7]
# b1 [7 5]
# k0 [7 7]
# n0 [4 7]
# n1 [6 5]
# p0 [1 0]
# p1 [2 4]
# p2 [3 3]
# p3 [3 4]
# p4 [4 5]
# p5 [5 6]
# p6 [6 0]
# p7 [6 7]
# q0 [2 2]
# r0 [1 3]
# r1 [2 3]
# B0 [2 0]
# B1 [3 1]
# K0 [5 1]
# N0 [1 6]
# N1 [3 5]
# P0 [0 3]
# P1 [1 1]
# P2 [4 1]
# P3 [4 2]
# P4 [5 0]
# P5 [6 6]
# P6 [7 0]
# P7 [7 4]
# Q0 [1 7]
# R0 [4 6]
# R1 [7 6]
# b0 [3 7]
# b1 [7 5]
# k0 [7 7]
# n0 [4 7]
# n1 [6 5]
# p0 [1 0]
# ...

# %%
# !zip -r Zipped_Boards.zip Boards/
# Out:
#   adding: Boards/ (stored 0%)
#   adding: Boards/1.png (deflated 0%)
#   adding: Boards/0.png (deflated 0%)

# %%
from google.colab import files
files.download("Zipped_Boards.zip")
